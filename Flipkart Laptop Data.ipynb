# %%
# libraries for Web Scrapping
import requests
from bs4 import BeautifulSoup

# library for advance string manipulation
import string

# library for data manipulation
import pandas as pd

# library for advance mathematical operations
import numpy as np

# importing os module 
import os 

# library for progress bar
from tqdm import tqdm

# libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Extract the html data from the webpage

# %%
# extract the data fro page number 1 only
page_number = 8

# extract the page as a whole
page = requests.get("https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=popularity&page={}".format(page_number))

# parse the whole page using a html parser
soup = BeautifulSoup(page.content, 'html.parser')
# soup

# %% [markdown]
# # Find thee main class that contains the group items

# %%
# find_all() searches for the all the tags where the class is found and 
# returns a list of all the occurences 
all_laps = soup.findAll('a', href=True, attrs={'class':"_31qSD5"})

# find the length of the elements extracted
len(all_laps)
# Out:
# 24

# %%
for a in all_laps:
    name = a.find(class_='_3auQ3N _2GcJzG')
    print(name)
    print('_______________________________________________')
# Out:
# <div class="_3auQ3N _2GcJzG">₹<!-- -->2,79,890</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->79,690</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->1,41,990</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->1,52,042</div>
# _______________________________________________
# None
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->21,325</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->1,02,990</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->1,94,900</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->61,850</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->1,39,999</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->90,990</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->56,144</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->52,240</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->1,24,999</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->55,431</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->1,53,990</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->1,04,435</div>
# _______________________________________________
# None
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->65,546</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->97,990</div>
# _______________________________________________
# None
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->77,890</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->99,990</div>
# _______________________________________________
# <div class="_3auQ3N _2GcJzG">₹<!-- -->40,871</div>
# _______________________________________________

# %%
data = []

for a in all_laps:
    
    processor = None
    ram = None
    os = None
    storage = None
    display = None
    
    name = a.find('div', attrs={'class':'_3wU53n'})
    ratings = a.find('div', attrs={'class':'hGSR34'})
    num_ratings = a.find('span', attrs={'class':'_38sUEc'})
    print(name.text)
    price = a.find(class_='_1vC4OE _2rQ-NK')
    org_price = a.find(class_='_3auQ3N _2GcJzG')
    print(price)
    
    allspecs = a.find('ul', attrs={'class':'vFw0gD'})
    sp = allspecs.findAll(class_="tVe95H")

    for i in range(len(sp)):
        if('Processor' in sp[i].text):
            processor = sp[i]
           
        elif('RAM' in sp[i].text):
            ram = sp[i]
            
        elif('OS' in sp[i].text or 'Operating' in sp[i].text):
            os = sp[i]
           
        elif('SSD' in sp[i].text or 'HDD' in sp[i].text):
            storage = sp[i]
            print(storage)
            
        elif('Display' in sp[i].text):
            display = sp[i]
            
            
    data.append({'name': name.text,
                 'ratings': ratings.text if ratings is not None else '',
                 'num_ratings': num_ratings.text if num_ratings is not None else '',
                'processor': processor,
                'ram': ram,
                'os': os,
                'storage': storage if storage is not None else '',
                'display': display,
                'price': price.text,
                'org_price': org_price.text if org_price is not None else ''})
    print('_______________')
# Out:
# Lenovo Legion 7i Core i7 10th Gen - (16 GB/1 TB SSD/Windows 10 Home/8 GB Graphics/NVIDIA Geforce RTX 2...
# <div class="_1vC4OE _2rQ-NK">₹1,95,990</div>
# <li class="tVe95H">1 TB SSD</li>
# _______________
# Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA G...
# <div class="_1vC4OE _2rQ-NK">₹55,990</div>
# <li class="tVe95H">1 TB HDD|256 GB SSD</li>
# _______________
# Asus ExpertBook B9 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home) ExpertBook B9 B9450FA Thin and...
# <div class="_1vC4OE _2rQ-NK">₹1,19,990</div>
# <li class="tVe95H">512 GB SSD</li>
# _______________
# HP Spectre x360 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Pro) 13-aw0211TU 2 in 1 Laptop
# <div class="_1vC4OE _2rQ-NK">₹1,27,990</div>
# <li class="tVe95H">512 GB SSD</li>
# _______________
# Lenovo Ideapad S145 APU Dual Core A6 A6-9225 - (4 GB/1 TB HDD/Windows 10 Home) S145-15AST Laptop
# <div class="_1vC4OE _2rQ-NK">₹27,890</div>
# <li class="tVe95H">1 TB HDD</li>
# _______________
# Lenovo Ideapad Slim APU Dual Core A4 A4-9120E - (4 GB/64 GB EMMC Storage/Windows 10 Home) 1-14AST-05 T...
# <div class="_1vC4OE _2rQ-NK">₹20,990</div>
# _______________
# Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX333FA-A4116T Thin and Light Lapt...
# <div class="_1vC4OE _2rQ-NK">₹82,990</div>
# <li class="tVe95H">512 GB SSD</li>
# _______________
# Apple MacBook Pro with Touch Bar Core i5 10th Gen - (16 GB/1 TB SSD/Mac OS Catalina) MWP82HN/A
# <div class="_1vC4OE _2rQ-NK">₹1,64,990</div>
# <li class="tVe95H">1 TB SSD</li>
# _______________
# Acer Aspire 5 Core i5 8th Gen - (8 GB + 16 GB Optane/1 TB HDD/Windows 10 Home) a515-52-555f Thin and L...
# <div class="_1vC4OE _2rQ-NK">₹54,990</div>
# <li class="tVe95H">1 TB HDD</li>
# _______________
# Microsoft Surface Pro 6 Core i7 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) 1796 2 in 1 Laptop
# <div class="_1vC4OE _2rQ-NK">₹1,35,990</div>
# <li class="tVe95H">256 GB SSD</li>
# _______________
# Asus ZenBook 13 Core i5 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX333FA-A4117T Thin and Light Lapt...
# <div class="_1vC4OE _2rQ-NK">₹69,990</div>
# <li class="tVe95H">512 GB SSD</li>
# _______________
# HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA Gefor...
# <div class="_1vC4OE _2rQ-NK">₹52,990</div>
# <li class="tVe95H">1 TB HDD</li>
# _______________
# Lenovo Ideapad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14IIL05 Thin and Light Laptop
# <div class="_1vC4OE _2rQ-NK">₹45,990</div>
# <li class="tVe95H">256 GB SSD</li>
# _______________
# Microsoft Surface Laptop 3 Ryzen 5 Quad Core 3580U - (8 GB/128 GB SSD/Windows 10 Home) 1873 Laptop
# <div class="_1vC4OE _2rQ-NK">₹1,18,990</div>
# <li class="tVe95H">128 GB SSD</li>
# _______________
# Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) X509JB-EJ592T Laptop
# <div class="_1vC4OE _2rQ-NK">₹51,990</div>
# <li class="tVe95H">512 GB SSD</li>
# _______________
# MSI GL65 Leopard Core i7 10th Gen - (16 GB/1 TB HDD/256 GB SSD/Windows 10 Home/6 GB Graphics/NVIDIA Ge...
# <div class="_1vC4OE _2rQ-NK">₹1,09,990</div>
# <li class="tVe95H">1 TB HDD|256 GB SSD</li>
# _______________
# Microsoft Surface Pro X SQ1 Octa Core - (8 GB/128 GB SSD/Windows 10 Home) M1876 Laptop
# <div class="_1vC4OE _2rQ-NK">₹98,490</div>
# <li class="tVe95H">128 GB SSD</li>
# _______________
# Asus Core i5 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) X412FA-EK296T Thin and Light Laptop
# <div class="_1vC4OE _2rQ-NK">₹58,990</div>
# <li class="tVe95H">512 GB SSD</li>
# _______________
# Acer Swift 3 Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) SF313-51-506P Thin and Light Laptop
# <div class="_1vC4OE _2rQ-NK">₹56,990</div>
# <li class="tVe95H">256 GB SSD</li>
# _______________
# Acer Predator Helios 300 Core i5 10th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NV...
# <div class="_1vC4OE _2rQ-NK">₹74,990</div>
# <li class="tVe95H">1 TB HDD|256 GB SSD</li>
# _______________
# Lenovo Ideapad 330s Core i5 8th Gen - (4 GB/1 TB HDD/Windows 10 Home/4 GB Graphics) 330S-15IKB Thin an...
# <div class="_1vC4OE _2rQ-NK">₹62,594</div>
# <li class="tVe95H">1 TB HDD</li>
# _______________
# Asus ROG Strix G Core i5 9th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA Gefo...
# <div class="_1vC4OE _2rQ-NK">₹59,990</div>
# <li class="tVe95H">1 TB HDD|256 GB SSD</li>
# _______________
# Asus ZenBook 14 Core i7 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX433FA-A6111T Thin and Light Lapt...
# <div class="_1vC4OE _2rQ-NK">₹85,990</div>
# <li class="tVe95H">512 GB SSD</li>
# _______________
# Asus Core i3 10th Gen - (4 GB/512 GB SSD/Windows 10 Home) X413JA-EK261T Thin and Light Laptop
# <div class="_1vC4OE _2rQ-NK">₹36,990</div>
# <li class="tVe95H">512 GB SSD</li>
# _______________

# %%
data
# Out:
# [{'name': 'Lenovo Legion 7i Core i7 10th Gen - (16 GB/1 TB SSD/Windows 10 Home/8 GB Graphics/NVIDIA Geforce RTX 2...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': <li class="tVe95H">Intel Core i7 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">16 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB SSD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹1,95,990',
#   'org_price': '₹2,79,890'},
#  {'name': 'Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA G...',
#   'ratings': '4.8',
#   'num_ratings': '51 Ratings\xa0&\xa06 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (9th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB HDD|256 GB SSD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹55,990',
#   'org_price': '₹79,690'},
#  {'name': 'Asus ExpertBook B9 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home) ExpertBook B9 B9450FA Thin and...',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB LPDDR3 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">512 GB SSD</li>,
#   'display': <li class="tVe95H">35.56 cm (14 inch) Display</li>,
#   'price': '₹1,19,990',
#   'org_price': '₹1,41,990'},
#  {'name': 'HP Spectre x360 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Pro) 13-aw0211TU 2 in 1 Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">512 GB SSD</li>,
#   'display': <li class="tVe95H">33.78 cm (13.3 inch) Touchscreen Display</li>,
#   'price': '₹1,27,990',
#   'org_price': '₹1,52,042'},
#  {'name': 'Lenovo Ideapad S145 APU Dual Core A6 A6-9225 - (4 GB/1 TB HDD/Windows 10 Home) S145-15AST Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': <li class="tVe95H">AMD APU Dual Core A6 Processor</li>,
#   'ram': <li class="tVe95H">4 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB HDD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹27,890',
#   'org_price': ''},
#  {'name': 'Lenovo Ideapad Slim APU Dual Core A4 A4-9120E - (4 GB/64 GB EMMC Storage/Windows 10 Home) 1-14AST-05 T...',
#   'ratings': '3.5',
#   'num_ratings': '827 Ratings\xa0&\xa0120 Reviews',
#   'processor': <li class="tVe95H">AMD APU Dual Core A4 Processor</li>,
#   'ram': <li class="tVe95H">4 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': '',
#   'display': <li class="tVe95H">35.56 cm (14 inch) Display</li>,
#   'price': '₹20,990',
#   'org_price': '₹21,325'},
#  {'name': 'Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX333FA-A4116T Thin and Light Lapt...',
#   'ratings': '4.4',
#   'num_ratings': '25 Ratings\xa0&\xa03 Reviews',
#   'processor': <li class="tVe95H">Intel Core i7 Processor (8th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR3 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">512 GB SSD</li>,
#   'display': <li class="tVe95H">33.78 cm (13.3 inch) Display</li>,
#   'price': '₹82,990',
#   'org_price': '₹1,02,990'},
#  {'name': 'Apple MacBook Pro with Touch Bar Core i5 10th Gen - (16 GB/1 TB SSD/Mac OS Catalina) MWP82HN/A',
#   'ratings': '5',
#   'num_ratings': '4 Ratings\xa0&\xa00 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">16 GB LPDDR4X RAM</li>,
#   'os': <li class="tVe95H">Mac OS Operating System</li>,
#   'storage': <li class="tVe95H">1 TB SSD</li>,
#   'display': <li class="tVe95H">33.02 cm (13 inch) Display</li>,
#   'price': '₹1,64,990',
#   'org_price': '₹1,94,900'},
#  {'name': 'Acer Aspire 5 Core i5 8th Gen - (8 GB + 16 GB Optane/1 TB HDD/Windows 10 Home) a515-52-555f Thin and L...',
#   'ratings': '4',
#   'num_ratings': '7 Ratings\xa0&\xa02 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (8th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB HDD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹54,990',
#   'org_price': '₹61,850'},
#  {'name': 'Microsoft Surface Pro 6 Core i7 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) 1796 2 in 1 Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': <li class="tVe95H">Intel Core i7 Processor (8th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR3 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">256 GB SSD</li>,
#   'display': <li class="tVe95H">31.24 cm (12.3 inch) Touchscreen Display</li>,
#   'price': '₹1,35,990',
#   'org_price': '₹1,39,999'},
#  {'name': 'Asus ZenBook 13 Core i5 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX333FA-A4117T Thin and Light Lapt...',
#   'ratings': '4.4',
#   'num_ratings': '12 Ratings\xa0&\xa02 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (8th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR3 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">512 GB SSD</li>,
#   'display': <li class="tVe95H">33.78 cm (13.3 inch) Display</li>,
#   'price': '₹69,990',
#   'org_price': '₹90,990'},
#  {'name': 'HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA Gefor...',
#   'ratings': '4.2',
#   'num_ratings': '3,151 Ratings\xa0&\xa0453 Reviews',
#   'processor': <li class="tVe95H">AMD Ryzen 5 Quad Core Processor</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB HDD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹52,990',
#   'org_price': '₹56,144'},
#  {'name': 'Lenovo Ideapad 3 Core i3 10th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14IIL05 Thin and Light Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': <li class="tVe95H">Intel Core i3 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">256 GB SSD</li>,
#   'display': <li class="tVe95H">35.56 cm (14 inch) Display</li>,
#   'price': '₹45,990',
#   'org_price': '₹52,240'},
#  {'name': 'Microsoft Surface Laptop 3 Ryzen 5 Quad Core 3580U - (8 GB/128 GB SSD/Windows 10 Home) 1873 Laptop',
#   'ratings': '5',
#   'num_ratings': '3 Ratings\xa0&\xa00 Reviews',
#   'processor': <li class="tVe95H">AMD Ryzen 5 Quad Core Processor</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">128 GB SSD</li>,
#   'display': <li class="tVe95H">38.1 cm (15 inch) Touchscreen Display</li>,
#   'price': '₹1,18,990',
#   'org_price': '₹1,24,999'},
#  {'name': 'Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/2 GB Graphics) X509JB-EJ592T Laptop',
#   'ratings': '4.1',
#   'num_ratings': '227 Ratings\xa0&\xa044 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">512 GB SSD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹51,990',
#   'org_price': '₹55,431'},
#  {'name': 'MSI GL65 Leopard Core i7 10th Gen - (16 GB/1 TB HDD/256 GB SSD/Windows 10 Home/6 GB Graphics/NVIDIA Ge...',
#   'ratings': '4.6',
#   'num_ratings': '61 Ratings\xa0&\xa011 Reviews',
#   'processor': <li class="tVe95H">Intel Core i7 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">16 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB HDD|256 GB SSD</li>,
#   'display': <li class="tVe95H">Matrix Display, Dragon Center, Cooler Boost 5, True Color 2.0, Nahimic 3</li>,
#   'price': '₹1,09,990',
#   'org_price': '₹1,53,990'},
#  {'name': 'Microsoft Surface Pro X SQ1 Octa Core - (8 GB/128 GB SSD/Windows 10 Home) M1876 Laptop',
#   'ratings': '4.2',
#   'num_ratings': '5 Ratings\xa0&\xa00 Reviews',
#   'processor': <li class="tVe95H">Microsoft SQ1 Octa Core Processor</li>,
#   'ram': <li class="tVe95H">8 GB LPDDR4X RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">128 GB SSD</li>,
#   'display': <li class="tVe95H">33.02 cm (13 inch) Touchscreen Display</li>,
#   'price': '₹98,490',
#   'org_price': '₹1,04,435'},
#  {'name': 'Asus Core i5 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) X412FA-EK296T Thin and Light Laptop',
#   'ratings': '',
#   'num_ratings': '',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (8th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">512 GB SSD</li>,
#   'display': <li class="tVe95H">35.56 cm (14 inch) Display</li>,
#   'price': '₹58,990',
#   'org_price': ''},
#  {'name': 'Acer Swift 3 Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) SF313-51-506P Thin and Light Laptop',
#   'ratings': '3.5',
#   'num_ratings': '17 Ratings\xa0&\xa06 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (8th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">256 GB SSD</li>,
#   'display': <li class="tVe95H">33.78 cm (13.3 inch) Display</li>,
#   'price': '₹56,990',
#   'org_price': '₹65,546'},
#  {'name': 'Acer Predator Helios 300 Core i5 10th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NV...',
#   'ratings': '4.8',
#   'num_ratings': '13 Ratings\xa0&\xa01 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB HDD|256 GB SSD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹74,990',
#   'org_price': '₹97,990'},
#  {'name': 'Lenovo Ideapad 330s Core i5 8th Gen - (4 GB/1 TB HDD/Windows 10 Home/4 GB Graphics) 330S-15IKB Thin an...',
#   'ratings': '4',
#   'num_ratings': '21 Ratings\xa0&\xa05 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (8th Gen)</li>,
#   'ram': <li class="tVe95H">4 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB HDD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹62,594',
#   'org_price': ''},
#  {'name': 'Asus ROG Strix G Core i5 9th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA Gefo...',
#   'ratings': '4.6',
#   'num_ratings': '3,825 Ratings\xa0&\xa0509 Reviews',
#   'processor': <li class="tVe95H">Intel Core i5 Processor (9th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">1 TB HDD|256 GB SSD</li>,
#   'display': <li class="tVe95H">39.62 cm (15.6 inch) Display</li>,
#   'price': '₹59,990',
#   'org_price': '₹77,890'},
#  {'name': 'Asus ZenBook 14 Core i7 8th Gen - (8 GB/512 GB SSD/Windows 10 Home) UX433FA-A6111T Thin and Light Lapt...',
#   'ratings': '4.5',
#   'num_ratings': '12 Ratings\xa0&\xa00 Reviews',
#   'processor': <li class="tVe95H">Intel Core i7 Processor (8th Gen)</li>,
#   'ram': <li class="tVe95H">8 GB DDR3 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">512 GB SSD</li>,
#   'display': <li class="tVe95H">35.56 cm (14 inch) Display</li>,
#   'price': '₹85,990',
#   'org_price': '₹99,990'},
#  {'name': 'Asus Core i3 10th Gen - (4 GB/512 GB SSD/Windows 10 Home) X413JA-EK261T Thin and Light Laptop',
#   'ratings': '4.6',
#   'num_ratings': '21 Ratings\xa0&\xa03 Reviews',
#   'processor': <li class="tVe95H">Intel Core i3 Processor (10th Gen)</li>,
#   'ram': <li class="tVe95H">4 GB DDR4 RAM</li>,
#   'os': <li class="tVe95H">64 bit Windows 10 Operating System</li>,
#   'storage': <li class="tVe95H">512 GB SSD</li>,
#   'display': <li class="tVe95H">35.56 cm (14 inch) Display</li>,
#   'price': '₹36,990',
#   'org_price': '₹40,871'}]

# %%
import pandas as pd 


"""data = [{'area': 'new-hills', 'rainfall': 100, 'temperature': 20}, 
        {'area': 'cape-town', 'rainfall': 70, 'temperature': 25}, 
        {'area': 'mumbai', 'rainfall': 200}] 
"""
df = pd.DataFrame.from_dict(data) 

df
# Out:
#                                                  name ratings  \
# 0   Lenovo Legion 7i Core i7 10th Gen - (16 GB/1 T...
# 1   Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...     4.8
# 2   Asus ExpertBook B9 Core i5 10th Gen - (8 GB/51...
# 3   HP Spectre x360 Core i5 10th Gen - (8 GB/512 G...
# 4   Lenovo Ideapad S145 APU Dual Core A6 A6-9225 -...
# 5   Lenovo Ideapad Slim APU Dual Core A4 A4-9120E ...     3.5
# 6   Asus ZenBook 13 Core i7 8th Gen - (8 GB/512 GB...     4.4
# 7   Apple MacBook Pro with Touch Bar Core i5 10th ...       5
# 8   Acer Aspire 5 Core i5 8th Gen - (8 GB + 16 GB ...       4
# 9   Microsoft Surface Pro 6 Core i7 8th Gen - (8 G...
# 10  Asus ZenBook 13 Core i5 8th Gen - (8 GB/512 GB...     4.4
# 11  HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (...     4.2
# 12  Lenovo Ideapad 3 Core i3 10th Gen - (8 GB/256 ...
# 13  Microsoft Surface Laptop 3 Ryzen 5 Quad Core 3...       5
# 14  Asus Core i5 10th Gen - (8 GB/512 GB SSD/Windo...     4.1
# 15  MSI GL65 Leopard Core i7 10th Gen - (16 GB/1 T...     4.6
# 16  Microsoft Surface Pro X SQ1 Octa Core - (8 GB/...     4.2
# 17  Asus Core i5 8th Gen - (8 GB/512 GB SSD/Window...
# 18  Acer Swift 3 Core i5 8th Gen - (8 GB/256 GB SS...     3.5
# 19  Acer Predator Helios 300 Core i5 10th Gen - (8...     4.8
# 20  Lenovo Ideapad 330s Core i5 8th Gen - (4 GB/1 ...       4
# 21  Asus ROG Strix G Core i5 9th Gen - (8 GB/1 TB ...     4.6
# 22  Asus ZenBook 14 Core i7 8th Gen - (8 GB/512 GB...     4.5
# 23  Asus Core i3 10th Gen - (4 GB/512 GB SSD/Windo...     4.6
#
#                     num_ratings                             processor  \
# 0                                [Intel Core i7 Processor (10th Gen)]
# 1        51 Ratings & 6 Reviews   [Intel Core i5 Processor (9th Gen)]
# 2                                [Intel Core i5 Processor (10th Gen)]
# 3                                [Intel Core i5 Processor (10th Gen)]
# 4                                    [AMD APU Dual Core A6 Processor]
# 5     827 Ratings & 120 Reviews      [AMD APU Dual Core A4 Processor]
# 6        25 Ratings & 3 Reviews   [Intel Core i7 Processor (8th Gen)]
# 7         4 Ratings & 0 Reviews  [Intel Core i5 Processor (10th Gen)]
# 8         7 Ratings & 2 Reviews   [Intel Core i5 Processor (8th Gen)]
# 9                                 [Intel Core i7 Processor (8th Gen)]
# 10       12 Ratings & 2 Reviews   [Intel Core i5 Processor (8th Gen)]
# 11  3,151 Ratings & 453 Reviews     [AMD Ryzen 5 Quad Core Processor]
# 12                               [Intel Core i3 Processor (10th Gen)]
# 13        3 Ratings & 0 Reviews     [AMD Ryzen 5 Quad Core Processor]
# 14     227 Ratings & 44 Reviews  [Intel Core i5 Processor (10th Gen)]
# 15      61 Ratings & 11 Reviews  [Intel Core i7 Processor (10th Gen)]
# 16        5 Ratings & 0 Reviews   [Microsoft SQ1 Octa Core Processor]
# 17                                [Intel Core i5 Processor (8th Gen)]
# 18       17 Ratings & 6 Reviews   [Intel Core i5 Processor (8th Gen)]
# 19       13 Ratings & 1 Reviews  [Intel Core i5 Processor (10th Gen)]
# 20       21 Ratings & 5 Reviews   [Intel Core i5 Processor (8th Gen)]
# 21  3,825 Ratings & 509 Reviews   [Intel Core i5 Processor (9th Gen)]
# 22       12 Ratings & 0 Reviews   [Intel Core i7 Processor (8th Gen)]
# 23       21 Ratings & 3 Reviews  [Intel Core i3 Processor (10th Gen)]
#
#                     ram                                    os  \
# 0      [16 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 1       [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 2     [8 GB LPDDR3 RAM]  [64 bit Windows 10 Operating System]
# 3       [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 4       [4 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 5       [4 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 6       [8 GB DDR3 RAM]  [64 bit Windows 10 Operating System]
# 7   [16 GB LPDDR4X RAM]             [Mac OS Operating System]
# 8       [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 9       [8 GB DDR3 RAM]  [64 bit Windows 10 Operating System]
# 10      [8 GB DDR3 RAM]  [64 bit Windows 10 Operating System]
# 11      [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 12      [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 13      [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 14      [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 15     [16 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 16   [8 GB LPDDR4X RAM]  [64 bit Windows 10 Operating System]
# 17      [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 18      [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 19      [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 20      [4 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 21      [8 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
# 22      [8 GB DDR3 RAM]  [64 bit Windows 10 Operating System]
# 23      [4 GB DDR4 RAM]  [64 bit Windows 10 Operating System]
#
#                   storage                                            display  \
# 0              [1 TB SSD]                     [39.62 cm (15.6 inch) Display]
# 1   [1 TB HDD|256 GB SSD]                     [39.62 cm (15.6 inch) Display]
# 2            [512 GB SSD]                       [35.56 cm (14 inch) Display]
# 3            [512 GB SSD]         [33.78 cm (13.3 inch) Touchscreen Display]
# 4              [1 TB HDD]                     [39.62 cm (15.6 inch) Display]
# 5                                               [35.56 cm (14 inch) Display]
# 6            [512 GB SSD]                     [33.78 cm (13.3 inch) Display]
# 7              [1 TB SSD]                       [33.02 cm (13 inch) Display]
# 8              [1 TB HDD]                     [39.62 cm (15.6 inch) Display]
# 9            [256 GB SSD]         [31.24 cm (12.3 inch) Touchscreen Display]
# 10           [512 GB SSD]                     [33.78 cm (13.3 inch) Display]
# 11             [1 TB HDD]                     [39.62 cm (15.6 inch) Display]
# 12           [256 GB SSD]                       [35.56 cm (14 inch) Display]
# 13           [128 GB SSD]            [38.1 cm (15 inch) Touchscreen Display]
# 14           [512 GB SSD]                     [39.62 cm (15.6 inch) Display]
# 15  [1 TB HDD|256 GB SSD]  [Matrix Display, Dragon Center, Cooler Boost 5...
# 16           [128 GB SSD]           [33.02 cm (13 inch) Touchscreen Display]
# 17           [512 GB SSD]                       [35.56 cm (14 inch) Display]
# 18           [256 GB SSD]                     [33.78 cm (13.3 inch) Display]
# 19  [1 TB HDD|256 GB SSD]                     [39.62 cm (15.6 inch) Display]
# 20             [1 TB HDD]                     [39.62 cm (15.6 inch) Display]
# 21  [1 TB HDD|256 GB SSD]                     [39.62 cm (15.6 inch) Display]
# 22           [512 GB SSD]                       [35.56 cm (14 inch) Display]
# 23           [512 GB SSD]                       [35.56 cm (14 inch) Display]
#
#         price  org_price
# 0   ₹1,95,990  ₹2,79,890
# 1     ₹55,990    ₹79,690
# 2   ₹1,19,990  ₹1,41,990
# 3   ₹1,27,990  ₹1,52,042
# 4     ₹27,890
# 5     ₹20,990    ₹21,325
# 6     ₹82,990  ₹1,02,990
# 7   ₹1,64,990  ₹1,94,900
# 8     ₹54,990    ₹61,850
# 9   ₹1,35,990  ₹1,39,999
# 10    ₹69,990    ₹90,990
# 11    ₹52,990    ₹56,144
# 12    ₹45,990    ₹52,240
# 13  ₹1,18,990  ₹1,24,999
# 14    ₹51,990    ₹55,431
# 15  ₹1,09,990  ₹1,53,990
# 16    ₹98,490  ₹1,04,435
# 17    ₹58,990
# 18    ₹56,990    ₹65,546
# 19    ₹74,990    ₹97,990
# 20    ₹62,594
# 21    ₹59,990    ₹77,890
# 22    ₹85,990    ₹99,990
# 23    ₹36,990    ₹40,871

# %% [markdown]
# # complete app

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
# extract the data for page number 1 only
page_number = 25
data = []

for i in tqdm(range(1, page_number)):

    # extract the page as a whole
    page = requests.get("https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&sort=popularity&page={}".format(i))

    # parse the whole page using a html parser
    soup = BeautifulSoup(page.content, 'html.parser')
    # soup

    # find_all() searches for the all the tags where the class is found and 
    # returns a list of all the occurences 
    all_laps = soup.findAll('a', href=True, attrs={'class':"_31qSD5"})

    # find the length of the elements extracted
    len(all_laps)

    for a in all_laps:
        
        processor = None
        ram = None
        os = None
        storage = None
        display = None

        name = a.find('div', attrs={'class':'_3wU53n'})
        ratings = a.find('div', attrs={'class':'hGSR34'})
        num_ratings = a.find('span', attrs={'class':'_38sUEc'})

        price = a.find(class_='_1vC4OE _2rQ-NK')
        org_price = a.find(class_='_3auQ3N _2GcJzG')


        allspecs = a.find('ul', attrs={'class':'vFw0gD'})
        sp = allspecs.findAll(class_="tVe95H")

        for i in range(len(sp)):
            if('Processor' in sp[i].text):
                processor = sp[i]

            elif('RAM' in sp[i].text):
                ram = sp[i]

            elif('Operating' in sp[i].text):
                os = sp[i]

            elif('SSD' in sp[i].text or 'HDD' in sp[i].text):
                storage = sp[i]

            elif('Display' in sp[i].text):
                display = sp[i]

        data.append({'name': name.text,
                     'ratings': ratings.text if ratings is not None else np.nan,
                     'num_ratings': num_ratings.text if num_ratings is not None else np.nan,
                    'processor': processor.text,
                    'ram': ram.text,
                    'os': os.text,
                    'storage': storage.text if storage is not None else np.nan,
                    'display': display.text,
                    'price': price.text,
                    'org_price': org_price.text if org_price is not None else np.nan})
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:34<00:00,  1.44s/it]

# %%
df = pd.DataFrame.from_dict(data) 

df
# Out:
#                                                   name ratings  \
# 0    Acer Aspire 7 Core i5 9th Gen - (8 GB/512 GB S...     4.5
# 1    Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...     4.7
# 2    Lenovo Ideapad L340 Core i5 9th Gen - (8 GB/1 ...     4.8
# 3    HP 14s Core i3 10th Gen - (8 GB/256 GB SSD/Win...     4.3
# 4    Dell Inspiron 3000 Core i5 10th Gen - (8 GB/1 ...     4.5
# ..                                                 ...     ...
# 547  Asus ZenBook 13 Core i5 8th Gen - (8 GB/512 GB...     4.5
# 548  Asus Athlon Dual Core 3050U - (4 GB/1 TB HDD/W...     NaN
# 549  Asus ROG Strix G Core i5 9th Gen - (8 GB/1 TB ...     4.6
# 550  Asus ROG Strix G Core i5 9th Gen - (8 GB/1 TB ...     4.5
# 551  Acer NITRO 5 Core i7 9th Gen - (8 GB/2 TB HDD/...     3.5
#
#                         num_ratings                           processor  \
# 0       5,311 Ratings & 977 Reviews   Intel Core i5 Processor (9th Gen)
# 1    25,623 Ratings & 2,871 Reviews   Intel Core i5 Processor (5th Gen)
# 2            51 Ratings & 6 Reviews   Intel Core i5 Processor (9th Gen)
# 3          116 Ratings & 14 Reviews  Intel Core i3 Processor (10th Gen)
# 4            47 Ratings & 3 Reviews  Intel Core i5 Processor (10th Gen)
# ..                              ...                                 ...
# 547        290 Ratings & 42 Reviews   Intel Core i5 Processor (8th Gen)
# 548                             NaN      AMD Athlon Dual Core Processor
# 549     3,825 Ratings & 509 Reviews   Intel Core i5 Processor (9th Gen)
# 550        173 Ratings & 30 Reviews   Intel Core i5 Processor (9th Gen)
# 551         36 Ratings & 15 Reviews   Intel Core i7 Processor (9th Gen)
#
#                ram                                  os              storage  \
# 0    8 GB DDR4 RAM  64 bit Windows 10 Operating System           512 GB SSD
# 1    8 GB DDR3 RAM      64 bit Mac OS Operating System           128 GB SSD
# 2    8 GB DDR4 RAM  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD
# 3    8 GB DDR4 RAM  64 bit Windows 10 Operating System           256 GB SSD
# 4    8 GB DDR4 RAM  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD
# ..             ...                                 ...                  ...
# 547  8 GB DDR4 RAM  64 bit Windows 10 Operating System           512 GB SSD
# 548  4 GB DDR4 RAM  64 bit Windows 10 Operating System             1 TB HDD
# 549  8 GB DDR4 RAM  64 bit Windows 10 Operating System  1 TB HDD|256 GB SSD
# 550  8 GB DDR4 RAM  64 bit Windows 10 Operating System             1 TB SSD
# 551  8 GB DDR4 RAM  64 bit Windows 10 Operating System  2 TB HDD|256 GB SSD
#
#                           display    price  org_price
# 0    39.62 cm (15.6 inch) Display  ₹49,990    ₹79,999
# 1    33.78 cm (13.3 inch) Display  ₹59,990    ₹84,900
# 2    39.62 cm (15.6 inch) Display  ₹55,990    ₹79,690
# 3      35.56 cm (14 inch) Display  ₹35,990    ₹42,103
# 4    39.62 cm (15.6 inch) Display  ₹55,990    ₹68,428
# ..                            ...      ...        ...
# 547  33.78 cm (13.3 inch) Display  ₹62,990    ₹82,383
# 548  39.62 cm (15.6 inch) Display  ₹27,990    ₹28,990
# 549  39.62 cm (15.6 inch) Display  ₹59,990    ₹77,890
# 550  39.62 cm (15.6 inch) Display  ₹69,990  ₹1,01,990
# 551  43.94 cm (17.3 inch) Display  ₹90,990  ₹1,45,999
#
# [552 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# name             0
# ratings        152
# num_ratings    152
# processor        0
# ram              0
# os               0
# storage         32
# display          0
# price            0
# org_price       94
# dtype: int64

# %%
df.to_csv('lappy_flipkart.csv', index=False)
